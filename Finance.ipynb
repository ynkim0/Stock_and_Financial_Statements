# %% [markdown]
# <a href="https://colab.research.google.com/github/ynkim0/Stock_and_Financial_Statements/blob/main/Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://psystat.tistory.com/151

# %%
# !pip install -U finance-datareader
# !pip install pykrx
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 12.9 MB/s
# ...
#      |████████████████████████████████| 52 kB 987 kB/s
# ...
#      |████████████████████████████████| 261 kB 59.8 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 722 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
from datetime import datetime

# %%
import FinanceDataReader as fdr
from pykrx import stock
import pandas_datareader.data as pdr
import yfinance as yf

# %%
import time

# %%
start_date = "2020-01-01"
end_date = "2022-12-07"

# %%
# 가장 최근 영업일의 시장별 종목리스트를 가져옴
stocks = fdr.StockListing('KRX') # 코스피, 코스닥, 코넥스 전체
stocks
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          58900          2
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         563000          1
# 2     207940  KR7207940008  삼성바이오로직스  KOSPI         831000          2
# 3     000660  KR7000660001    SK하이닉스  KOSPI          78900          2
# 4     006400  KR7006400006     삼성SDI  KOSPI         708000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2678  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2679  288490  KR7288490006     나라소프트  KONEX  일반기업부      49          2
# 2680  267810  KR7267810000        앙츠  KONEX  일반기업부    1000          2
# 2681  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2682  329020  KR7329020002      오션스톤  KONEX  일반기업부    1800          0
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# ...

# %%
stocks_list = stocks['Code'].tolist()
print(len(stocks_list))
# Out:
# 2683

# %%
# KRX stock delisting symbol list 상장폐지 종목 전체 리스트
krx_delisting = fdr.StockListing('KRX-DELISTING')

# %%
krx_delisting = krx_delisting.loc[krx_delisting['DelistingDate'] >= datetime(2020, 1, 1)]
stocks_list.extend(krx_delisting['Symbol'].tolist())
print(len(stocks_list))
# Out:
# 3085

# %%
stocks_dic = {}
for stock in stocks_list:
  df_fdr = fdr.DataReader(stock, start=start_date, end=end_date)
  if not df_fdr.empty:
    stocks_dic[stock] = df_fdr
# Out:
# "0791601A" invalid symbol or has no data
# "3655501B" invalid symbol or has no data
# "1305001B" invalid symbol or has no data
# "2948701A" invalid symbol or has no data
# "0827401C" invalid symbol or has no data
# "1196501B" invalid symbol or has no data
# "0000401A" invalid symbol or has no data
# "2184101B" invalid symbol or has no data
# "3954001C" invalid symbol or has no data
# "0118101B" invalid symbol or has no data
# "0005001C" invalid symbol or has no data
# "2177301B" invalid symbol or has no data
# "0539501C" invalid symbol or has no data
# "0901501B" invalid symbol or has no data
# "0076901B" invalid symbol or has no data
# "3077501B" invalid symbol or has no data
# "0948601B" invalid symbol or has no data
# "2906601A" invalid symbol or has no data
# "1947001C" invalid symbol or has no data
# "0682401B" invalid symbol or has no data
# "0682401C" invalid symbol or has no data
# "2903801C" invalid symbol or has no data
# "0014401C" invalid symbol or has no data
# ...

# %%
len(stocks_dic)
# Out:
# 2825

# %%
stocks_dic['373220']
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2022-01-27  597000  598000  450000  505000  15946992       NaN
# 2022-01-28  476000  483000  445000  450000   4559773 -0.108911
# 2022-02-03  458000  495500  441000  477000   2918435  0.060000
# 2022-02-04  476500  505000  476000  504000   2088996  0.056604
# 2022-02-07  520000  548000  511000  548000   1911176  0.087302
# ...            ...     ...     ...     ...       ...       ...
# 2022-12-01  589000  591000  579000  585000    360664 -0.003407
# 2022-12-02  585000  590000  578000  584000    239024 -0.001709
# 2022-12-05  582000  582000  562000  562000    370292 -0.037671
# 2022-12-06  555000  568000  553000  559000    249853 -0.005338
# 2022-12-07  558000  565000  553000  563000    209336  0.007156
#
# [212 rows x 6 columns]

# %%
import pickle

with open('stocks_dic.pkl','wb') as f:
  pickle.dump(stocks_dic,f)
